# %%
# pip install scikit-learn

# %%
import tensorflow as tf # Import Tensorflow
import numpy as np  # Import NumPy
import pandas as pd # Import Pandas
import matplotlib.pyplot as plt # Matplotlib Data Visualization Library
import seaborn as sns # Seaborn Data Visualization Library

from sklearn.model_selection import train_test_split # Import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler # Import LabelEncoder and MinMaxScaler

# %%
# Upload the CSV data and convert it to a Pandas DataFrame
df = pd.read_csv('./reduced_version_data_ENEL_645.csv', index_col='Community Name')
df.head()
# Out:
#                    Sector Group Category                  Category  \
# Community Name
# WHITEHORN       NORTHEAST          Crime            Street Robbery
# FOOTHILLS            EAST          Crime          Theft OF Vehicle
# ACADIA              SOUTH          Crime        Theft FROM Vehicle
# MAHOGANY        SOUTHEAST          Crime          Theft OF Vehicle
# LINCOLN PARK         WEST          Crime  Commercial Break & Enter
#
#                 Crime Count  Resident Count  Year Month
# Community Name
# WHITEHORN                 1           12019  2019   SEP
# FOOTHILLS                10             317  2019   NOV
# ACADIA                   13           10520  2019   SEP
# MAHOGANY                  1           11784  2019   NOV
# LINCOLN PARK              5            2617  2019   NOV

# %%
# View dimensions of the DataFrame
df.shape
# Out:
# (100000, 7)

# %%
# Check for null values
df.isnull().sum()
# Out:
# Sector            0
# Group Category    0
# Category          0
# Crime Count       0
# Resident Count    0
# Year              0
# Month             0
# dtype: int64

# %%
# Check all unique values for Category in the DataFrame
df['Category'].unique()
# Out:
# array(['Street Robbery', 'Theft OF Vehicle', 'Theft FROM Vehicle',
#        'Commercial Break & Enter', 'Social Disorder',
#        'Assault (Non-domestic)', 'Residential Break & Enter',
#        'Physical Disorder', 'Violence Other (Non-domestic)',
#        'Commercial Robbery', '1320.131'], dtype=object)

# %%
# Pop the Category column out of df and assign it to output vector y
y = df.pop('Category')
y
# Out:
# Community Name
# WHITEHORN                        Street Robbery
# FOOTHILLS                      Theft OF Vehicle
# ACADIA                       Theft FROM Vehicle
# MAHOGANY                       Theft OF Vehicle
# LINCOLN PARK           Commercial Break & Enter
#                                  ...
# WOODBINE                      Physical Disorder
# NORTH GLENMORE PARK      Assault (Non-domestic)
# HAYSBORO                      Physical Disorder
# FAIRVIEW INDUSTRIAL             Social Disorder
# KILLARNEY/GLENGARRY            Theft OF Vehicle
# Name: Category, Length: 100000, dtype: object

# %%
# Create a separate DataFrame with only the categorical features of df
categorical_columns_df = df[['Sector', 'Month', 'Group Category']]
categorical_columns_df
# Out:
#                         Sector Month Group Category
# Community Name
# WHITEHORN            NORTHEAST   SEP          Crime
# FOOTHILLS                 EAST   NOV          Crime
# ACADIA                   SOUTH   SEP          Crime
# MAHOGANY             SOUTHEAST   NOV          Crime
# LINCOLN PARK              WEST   NOV          Crime
# ...                        ...   ...            ...
# WOODBINE                 SOUTH   JAN       Disorder
# NORTH GLENMORE PARK       WEST   MAR          Crime
# HAYSBORO                 SOUTH   SEP       Disorder
# FAIRVIEW INDUSTRIAL      SOUTH   MAR       Disorder
# KILLARNEY/GLENGARRY     CENTRE   OCT          Crime
#
# [100000 rows x 3 columns]

# %%
# Use get_dummies to One Hot Encode the categorical_columns_df
categorical_columns_df_enc = pd.get_dummies(data=categorical_columns_df)
categorical_columns_df_enc
# Out:
#                      Sector_CENTRE  Sector_EAST  Sector_NORTH  \
# Community Name
# WHITEHORN                        0            0             0
# FOOTHILLS                        0            1             0
# ACADIA                           0            0             0
# MAHOGANY                         0            0             0
# LINCOLN PARK                     0            0             0
# ...                            ...          ...           ...
# WOODBINE                         0            0             0
# NORTH GLENMORE PARK              0            0             0
# HAYSBORO                         0            0             0
# FAIRVIEW INDUSTRIAL              0            0             0
# KILLARNEY/GLENGARRY              1            0             0
#
#                      Sector_NORTHEAST  Sector_NORTHWEST  Sector_SOUTH  \
# Community Name
# WHITEHORN                           1                 0             0
# FOOTHILLS                           0                 0             0
# ACADIA                              0                 0             1
# MAHOGANY                            0                 0             0
# LINCOLN PARK                        0                 0             0
# ...                               ...               ...           ...
# WOODBINE                            0                 0             1
# NORTH GLENMORE PARK                 0                 0             0
# HAYSBORO                            0                 0             1
# FAIRVIEW INDUSTRIAL                 0                 0             1
# KILLARNEY/GLENGARRY                 0                 0             0
#
#                      Sector_SOUTHEAST  Sector_WEST  Month_APR  Month_AUG  \
# Community Name
# WHITEHORN                           0            0          0          0
# FOOTHILLS                           0            0          0          0
# ACADIA                              0            0          0          0
# MAHOGANY                            1            0          0          0
# LINCOLN PARK                        0            1          0          0
# ...                               ...          ...        ...        ...
# WOODBINE                            0            0          0          0
# NORTH GLENMORE PARK                 0            1          0          0
# HAYSBORO                            0            0          0          0
# FAIRVIEW INDUSTRIAL                 0            0          0          0
# KILLARNEY/GLENGARRY                 0            0          0          0
#
#                      Month_DEC  Month_FEB  Month_JAN  Month_JUL  Month_JUN  \
# Community Name
# WHITEHORN                    0          0          0          0          0
# FOOTHILLS                    0          0          0          0          0
# ACADIA                       0          0          0          0          0
# MAHOGANY                     0          0          0          0          0
# LINCOLN PARK                 0          0          0          0          0
# ...                        ...        ...        ...        ...        ...
# WOODBINE                     0          0          1          0          0
# NORTH GLENMORE PARK          0          0          0          0          0
# HAYSBORO                     0          0          0          0          0
# FAIRVIEW INDUSTRIAL          0          0          0          0          0
# KILLARNEY/GLENGARRY          0          0          0          0          0
#
#                      Month_MAR  Month_MAY  Month_NOV  Month_OCT  Month_SEP  \
# Community Name
# WHITEHORN                    0          0          0          0          1
# FOOTHILLS                    0          0          1          0          0
# ACADIA                       0          0          0          0          1
# MAHOGANY                     0          0          1          0          0
# LINCOLN PARK                 0          0          1          0          0
# ...                        ...        ...        ...        ...        ...
# WOODBINE                     0          0          0          0          0
# NORTH GLENMORE PARK          1          0          0          0          0
# HAYSBORO                     0          0          0          0          1
# FAIRVIEW INDUSTRIAL          1          0          0          0          0
# KILLARNEY/GLENGARRY          0          0          0          1          0
#
#                      Group Category_Crime  Group Category_Disorder
# Community Name
# WHITEHORN                               1                        0
# FOOTHILLS                               1                        0
# ACADIA                                  1                        0
# MAHOGANY                                1                        0
# LINCOLN PARK                            1                        0
# ...                                   ...                      ...
# WOODBINE                                0                        1
# NORTH GLENMORE PARK                     1                        0
# HAYSBORO                                0                        1
# FAIRVIEW INDUSTRIAL                     0                        1
# KILLARNEY/GLENGARRY                     1                        0
#
# [100000 rows x 22 columns]

# %%
# Form features matrix X by combining the Encoded categorical Features with the numerical features
X = pd.concat([df[['Crime Count', 'Resident Count', 'Year']], categorical_columns_df_enc], axis=1)
X
# Out:
#                      Crime Count  Resident Count  Year  Sector_CENTRE  \
# Community Name
# WHITEHORN                      1           12019  2019              0
# FOOTHILLS                     10             317  2019              0
# ACADIA                        13           10520  2019              0
# MAHOGANY                       1           11784  2019              0
# LINCOLN PARK                   5            2617  2019              0
# ...                          ...             ...   ...            ...
# WOODBINE                       2            9131  2013              0
# NORTH GLENMORE PARK            2            2333  2014              0
# HAYSBORO                       5            6943  2012              0
# FAIRVIEW INDUSTRIAL            7               0  2013              0
# KILLARNEY/GLENGARRY            1            6870  2013              1
#
#                      Sector_EAST  Sector_NORTH  Sector_NORTHEAST  \
# Community Name
# WHITEHORN                      0             0                 1
# FOOTHILLS                      1             0                 0
# ACADIA                         0             0                 0
# MAHOGANY                       0             0                 0
# LINCOLN PARK                   0             0                 0
# ...                          ...           ...               ...
# WOODBINE                       0             0                 0
# NORTH GLENMORE PARK            0             0                 0
# HAYSBORO                       0             0                 0
# FAIRVIEW INDUSTRIAL            0             0                 0
# KILLARNEY/GLENGARRY            0             0                 0
#
#                      Sector_NORTHWEST  Sector_SOUTH  Sector_SOUTHEAST  \
# Community Name
# WHITEHORN                           0             0                 0
# FOOTHILLS                           0             0                 0
# ACADIA                              0             1                 0
# MAHOGANY                            0             0                 1
# LINCOLN PARK                        0             0                 0
# ...                               ...           ...               ...
# WOODBINE                            0             1                 0
# NORTH GLENMORE PARK                 0             0                 0
# HAYSBORO                            0             1                 0
# FAIRVIEW INDUSTRIAL                 0             1                 0
# KILLARNEY/GLENGARRY                 0             0                 0
#
#                      Sector_WEST  Month_APR  Month_AUG  Month_DEC  Month_FEB  \
# Community Name
# WHITEHORN                      0          0          0          0          0
# FOOTHILLS                      0          0          0          0          0
# ACADIA                         0          0          0          0          0
# MAHOGANY                       0          0          0          0          0
# LINCOLN PARK                   1          0          0          0          0
# ...                          ...        ...        ...        ...        ...
# WOODBINE                       0          0          0          0          0
# NORTH GLENMORE PARK            1          0          0          0          0
# HAYSBORO                       0          0          0          0          0
# FAIRVIEW INDUSTRIAL            0          0          0          0          0
# KILLARNEY/GLENGARRY            0          0          0          0          0
#
#                      Month_JAN  Month_JUL  Month_JUN  Month_MAR  Month_MAY  \
# Community Name
# WHITEHORN                    0          0          0          0          0
# FOOTHILLS                    0          0          0          0          0
# ACADIA                       0          0          0          0          0
# MAHOGANY                     0          0          0          0          0
# LINCOLN PARK                 0          0          0          0          0
# ...                        ...        ...        ...        ...        ...
# WOODBINE                     1          0          0          0          0
# NORTH GLENMORE PARK          0          0          0          1          0
# HAYSBORO                     0          0          0          0          0
# FAIRVIEW INDUSTRIAL          0          0          0          1          0
# KILLARNEY/GLENGARRY          0          0          0          0          0
#
#                      Month_NOV  Month_OCT  Month_SEP  Group Category_Crime  \
# Community Name
# WHITEHORN                    0          0          1                     1
# FOOTHILLS                    1          0          0                     1
# ACADIA                       0          0          1                     1
# MAHOGANY                     1          0          0                     1
# LINCOLN PARK                 1          0          0                     1
# ...                        ...        ...        ...                   ...
# WOODBINE                     0          0          0                     0
# NORTH GLENMORE PARK          0          0          0                     1
# HAYSBORO                     0          0          1                     0
# FAIRVIEW INDUSTRIAL          0          0          0                     0
# KILLARNEY/GLENGARRY          0          1          0                     1
#
#                      Group Category_Disorder
# Community Name
# WHITEHORN                                  0
# FOOTHILLS                                  0
# ACADIA                                     0
# MAHOGANY                                   0
# LINCOLN PARK                               0
# ...                                      ...
# WOODBINE                                   1
# NORTH GLENMORE PARK                        0
# HAYSBORO                                   1
# FAIRVIEW INDUSTRIAL                        1
# KILLARNEY/GLENGARRY                        0
#
# [100000 rows x 25 columns]

# %%
# Instantiate MinMaxScaler object
scaler = MinMaxScaler() 
scaler.fit(X) # Fit scaler to features matrix X
X_scaled = scaler.transform(X) # Transform X using Scaler to create X_scaled

# %%
label_encoder = LabelEncoder() # Instantiate LabelEncoder object
label_encoder.fit(y) # Fit encoder to output vector y
y_enc = label_encoder.transform(y) # Transform y using Scaler to create y_enc

print(f"Shape of y_enc: {y_enc.shape}") # Check dimensions  of y_enc
y_enc
# Out:
# Shape of y_enc: (100000,)
# array([7, 9, 8, ..., 4, 6, 9])

# %%
X_scaled # View preview of Features Matrix X
# Out:
# array([[0.        , 0.4624471 , 1.        , ..., 1.        , 1.        ,
#         0.        ],
#        [0.01153846, 0.012197  , 1.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.01538462, 0.40477107, 1.        , ..., 1.        , 1.        ,
#         0.        ],
#        ...,
#        [0.00512821, 0.26714121, 0.        , ..., 1.        , 0.        ,
#         1.        ],
#        [0.00769231, 0.        , 0.14285714, ..., 0.        , 0.        ,
#         1.        ],
#        [0.        , 0.26433244, 0.14285714, ..., 0.        , 1.        ,
#         0.        ]])

# %%
# Split arrays or matrices into random train and test subsets. Use 70/30 split.
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_enc, train_size=0.7, random_state=39)

# %%
# View dimensions of the Features Matrix X and Output Column y for both training and testing sets
print(f"Dimensions of X_train: {X_train.shape}")
print(f"Dimensions of X_test: {X_test.shape}")
print(f"Dimensions of y_train: {y_train.shape}")
print(f"Dimensions of y_test: {y_test.shape}")

# Conversion needed to pass X_train to model fit method
X_train = np.asarray(X_train).astype(np.float32) 
# Conversion needed to pass y_train to model fit method
y_train = np.asarray(y_train).astype(np.float32)
# Out:
# Dimensions of X_train: (70000, 25)
# Dimensions of X_test: (30000, 25)
# Dimensions of y_train: (70000,)
# Dimensions of y_test: (30000,)

# %%
number_of_output_labels = y.nunique() # Count the number of unique labels in y
print(number_of_output_labels) # Print the number of unique labels in y

# Create Neural Network Model with 6 layers
model = tf.keras.Sequential ([
    tf.keras.layers.Dense (512, input_shape = (X_train.shape[1], ), activation = 'relu'),
    tf.keras.layers.Dense (256, activation = 'relu'),
    tf.keras.layers.Dense (128, activation = 'relu'),
    tf.keras.layers.Dense (64, activation = 'relu'),
    tf.keras.layers.Dense (32, activation = 'relu'),
    tf.keras.layers.Dense (number_of_output_labels, activation = 'softmax')
])
# Out:
# 11

# %%
# Adam optimization: a gradient descent method that is "computationally efficient, has little memory requirement, 
# invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters"

# Use this SparseCategoricalCrossentropy crossentropy loss function when there are two or more label classes. 

# Accuracy metric: calculates how often predictions equal labels.
model.compile(tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss=tf.keras.losses.SparseCategoricalCrossentropy(), 
              metrics=['accuracy'])

# %%
model.summary() # Print model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               13312
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 11)                363
#
# =================================================================
# Total params: 188,235
# Trainable params: 188,235
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Enables / disables eager execution of tf.functions. Needed to prevent an error for this code
tf.config.run_functions_eagerly(True)
model.fit(X_train, y_train, epochs=15)
# Out:
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/structured_function.py:254: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   warnings.warn(
# 2188/2188 [==============================] - 120s 53ms/step - loss: 1.5227 - accuracy: 0.3620
# Epoch 2/15
# 2188/2188 [==============================] - 117s 54ms/step - loss: 1.3854 - accuracy: 0.4272
# Epoch 3/15
# 2188/2188 [==============================] - 117s 53ms/step - loss: 1.3308 - accuracy: 0.4536
# Epoch 4/15
# 2188/2188 [==============================] - 116s 53ms/step - loss: 1.3128 - accuracy: 0.4619
# Epoch 5/15
# 2188/2188 [==============================] - 116s 53ms/step - loss: 1.2949 - accuracy: 0.4738
# Epoch 6/15
# 2188/2188 [==============================] - 116s 53ms/step - loss: 1.2770 - accuracy: 0.4803
# Epoch 7/15
# 2188/2188 [==============================] - 115s 53ms/step - loss: 1.2654 - accuracy: 0.4813
# Epoch 8/15
# 2188/2188 [==============================] - 115s 52ms/step - loss: 1.2545 - accuracy: 0.4859
# Epoch 9/15
# 2188/2188 [==============================] - 115s 52ms/step - loss: 1.2476 - accuracy: 0.4862
# Epoch 10/15
# 2188/2188 [==============================] - 114s 52ms/step - loss: 1.2397 - accuracy: 0.4877
# Epoch 11/15
# 2188/2188 [==============================] - 115s 53ms/step - loss: 1.2344 - accuracy: 0.4906
# Epoch 12/15
# 2188/2188 [==============================] - 115s 52ms/step - loss: 1.2288 - accuracy: 0.4915
# Epoch 13/15
# 2188/2188 [==============================] - 116s 53ms/step - loss: 1.2261 - accuracy: 0.4917
# Epoch 14/15
# 2188/2188 [==============================] - 116s 53ms/step - loss: 1.2209 - accuracy: 0.4926
# Epoch 15/15
# 2188/2188 [==============================] - 115s 52ms/step - loss: 1.2198 - accuracy: 0.4929

# %%
# Conversion needed to pass X_test to model evaluate method
X_test = np.asarray(X_test).astype(np.float32)
# Conversion needed to pass y_test to model evaluate method
y_test = np.asarray(y_test).astype(np.float32) 
model.evaluate(X_test, y_test)
# Out:
# 938/938 [==============================] - 15s 15ms/step - loss: 1.2175 - accuracy: 0.4932
# [1.217498779296875, 0.49316665530204773]
