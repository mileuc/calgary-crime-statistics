# %%
# pip install scikit-learn

# %%
import tensorflow as tf # Import Tensorflow
import numpy as np  # Import NumPy
import pandas as pd # Import Pandas
import matplotlib.pyplot as plt # Matplotlib Data Visualization Library
import seaborn as sns # Seaborn Data Visualization Library

from sklearn.model_selection import train_test_split # Import train_test_split 
from sklearn.preprocessing import LabelEncoder, MinMaxScaler # Import Label Encode and MinMaxScaler

# %%
# Upload the CSV data and convert it to a Pandas DataFrame
df = pd.read_csv('./reduced_version_data_ENEL_645.csv', index_col='Community Name')
df.head()
# Out:
#                    Sector Group Category                  Category  \
# Community Name
# WHITEHORN       NORTHEAST          Crime            Street Robbery
# FOOTHILLS            EAST          Crime          Theft OF Vehicle
# ACADIA              SOUTH          Crime        Theft FROM Vehicle
# MAHOGANY        SOUTHEAST          Crime          Theft OF Vehicle
# LINCOLN PARK         WEST          Crime  Commercial Break & Enter
#
#                 Crime Count  Resident Count  Year Month
# Community Name
# WHITEHORN                 1           12019  2019   SEP
# FOOTHILLS                10             317  2019   NOV
# ACADIA                   13           10520  2019   SEP
# MAHOGANY                  1           11784  2019   NOV
# LINCOLN PARK              5            2617  2019   NOV

# %%
# View dimensions of the DataFrame
df.shape
# Out:
# (100000, 7)

# %%
# Check for null values
df.isnull().sum()
# Out:
# Sector            0
# Group Category    0
# Category          0
# Crime Count       0
# Resident Count    0
# Year              0
# Month             0
# dtype: int64

# %%
# Pop the Crime Count column out of df and assign it to output vector y
y = df.pop('Crime Count')
y
# Out:
# Community Name
# WHITEHORN               1
# FOOTHILLS              10
# ACADIA                 13
# MAHOGANY                1
# LINCOLN PARK            5
#                        ..
# WOODBINE                2
# NORTH GLENMORE PARK     2
# HAYSBORO                5
# FAIRVIEW INDUSTRIAL     7
# KILLARNEY/GLENGARRY     1
# Name: Crime Count, Length: 100000, dtype: int64

# %%
# Create a separate DataFrame with only the categorical features of df
categorical_columns_df = df[['Sector', 'Month', 'Group Category', 'Category']]
categorical_columns_df
# Out:
#                         Sector Month Group Category                  Category
# Community Name
# WHITEHORN            NORTHEAST   SEP          Crime            Street Robbery
# FOOTHILLS                 EAST   NOV          Crime          Theft OF Vehicle
# ACADIA                   SOUTH   SEP          Crime        Theft FROM Vehicle
# MAHOGANY             SOUTHEAST   NOV          Crime          Theft OF Vehicle
# LINCOLN PARK              WEST   NOV          Crime  Commercial Break & Enter
# ...                        ...   ...            ...                       ...
# WOODBINE                 SOUTH   JAN       Disorder         Physical Disorder
# NORTH GLENMORE PARK       WEST   MAR          Crime    Assault (Non-domestic)
# HAYSBORO                 SOUTH   SEP       Disorder         Physical Disorder
# FAIRVIEW INDUSTRIAL      SOUTH   MAR       Disorder           Social Disorder
# KILLARNEY/GLENGARRY     CENTRE   OCT          Crime          Theft OF Vehicle
#
# [100000 rows x 4 columns]

# %%
# Use get_dummies to One Hot Encode the categorical_columns_df
categorical_columns_df_enc = pd.get_dummies(data=categorical_columns_df)
categorical_columns_df_enc
# Out:
#                      Sector_CENTRE  Sector_EAST  Sector_NORTH  \
# Community Name
# WHITEHORN                        0            0             0
# FOOTHILLS                        0            1             0
# ACADIA                           0            0             0
# MAHOGANY                         0            0             0
# LINCOLN PARK                     0            0             0
# ...                            ...          ...           ...
# WOODBINE                         0            0             0
# NORTH GLENMORE PARK              0            0             0
# HAYSBORO                         0            0             0
# FAIRVIEW INDUSTRIAL              0            0             0
# KILLARNEY/GLENGARRY              1            0             0
#
#                      Sector_NORTHEAST  Sector_NORTHWEST  Sector_SOUTH  \
# Community Name
# WHITEHORN                           1                 0             0
# FOOTHILLS                           0                 0             0
# ACADIA                              0                 0             1
# MAHOGANY                            0                 0             0
# LINCOLN PARK                        0                 0             0
# ...                               ...               ...           ...
# WOODBINE                            0                 0             1
# NORTH GLENMORE PARK                 0                 0             0
# HAYSBORO                            0                 0             1
# FAIRVIEW INDUSTRIAL                 0                 0             1
# KILLARNEY/GLENGARRY                 0                 0             0
#
#                      Sector_SOUTHEAST  Sector_WEST  Month_APR  Month_AUG  ...  \
# Community Name                                                            ...
# WHITEHORN                           0            0          0          0  ...
# FOOTHILLS                           0            0          0          0  ...
# ACADIA                              0            0          0          0  ...
# MAHOGANY                            1            0          0          0  ...
# LINCOLN PARK                        0            1          0          0  ...
# ...                               ...          ...        ...        ...  ...
# WOODBINE                            0            0          0          0  ...
# NORTH GLENMORE PARK                 0            1          0          0  ...
# HAYSBORO                            0            0          0          0  ...
# FAIRVIEW INDUSTRIAL                 0            0          0          0  ...
# KILLARNEY/GLENGARRY                 0            0          0          0  ...
#
#                      Category_Assault (Non-domestic)  \
# Community Name
# WHITEHORN                                          0
# FOOTHILLS                                          0
# ACADIA                                             0
# MAHOGANY                                           0
# LINCOLN PARK                                       0
# ...                                              ...
# WOODBINE                                           0
# NORTH GLENMORE PARK                                1
# HAYSBORO                                           0
# FAIRVIEW INDUSTRIAL                                0
# KILLARNEY/GLENGARRY                                0
#
#                      Category_Commercial Break & Enter  \
# Community Name
# WHITEHORN                                            0
# FOOTHILLS                                            0
# ACADIA                                               0
# MAHOGANY                                             0
# LINCOLN PARK                                         1
# ...                                                ...
# WOODBINE                                             0
# NORTH GLENMORE PARK                                  0
# HAYSBORO                                             0
# FAIRVIEW INDUSTRIAL                                  0
# KILLARNEY/GLENGARRY                                  0
#
#                      Category_Commercial Robbery  Category_Physical Disorder  \
# Community Name
# WHITEHORN                                      0                           0
# FOOTHILLS                                      0                           0
# ACADIA                                         0                           0
# MAHOGANY                                       0                           0
# LINCOLN PARK                                   0                           0
# ...                                          ...                         ...
# WOODBINE                                       0                           1
# NORTH GLENMORE PARK                            0                           0
# HAYSBORO                                       0                           1
# FAIRVIEW INDUSTRIAL                            0                           0
# KILLARNEY/GLENGARRY                            0                           0
#
#                      Category_Residential Break & Enter  \
# Community Name
# WHITEHORN                                             0
# FOOTHILLS                                             0
# ACADIA                                                0
# MAHOGANY                                              0
# LINCOLN PARK                                          0
# ...                                                 ...
# WOODBINE                                              0
# NORTH GLENMORE PARK                                   0
# HAYSBORO                                              0
# FAIRVIEW INDUSTRIAL                                   0
# KILLARNEY/GLENGARRY                                   0
#
#                      Category_Social Disorder  Category_Street Robbery  \
# Community Name
# WHITEHORN                                   0                        1
# FOOTHILLS                                   0                        0
# ACADIA                                      0                        0
# MAHOGANY                                    0                        0
# LINCOLN PARK                                0                        0
# ...                                       ...                      ...
# WOODBINE                                    0                        0
# NORTH GLENMORE PARK                         0                        0
# HAYSBORO                                    0                        0
# FAIRVIEW INDUSTRIAL                         1                        0
# KILLARNEY/GLENGARRY                         0                        0
#
#                      Category_Theft FROM Vehicle  Category_Theft OF Vehicle  \
# Community Name
# WHITEHORN                                      0                          0
# FOOTHILLS                                      0                          1
# ACADIA                                         1                          0
# MAHOGANY                                       0                          1
# LINCOLN PARK                                   0                          0
# ...                                          ...                        ...
# WOODBINE                                       0                          0
# NORTH GLENMORE PARK                            0                          0
# HAYSBORO                                       0                          0
# FAIRVIEW INDUSTRIAL                            0                          0
# KILLARNEY/GLENGARRY                            0                          1
#
#                      Category_Violence Other (Non-domestic)
# Community Name
# WHITEHORN                                                 0
# FOOTHILLS                                                 0
# ACADIA                                                    0
# MAHOGANY                                                  0
# LINCOLN PARK                                              0
# ...                                                     ...
# WOODBINE                                                  0
# NORTH GLENMORE PARK                                       0
# HAYSBORO                                                  0
# FAIRVIEW INDUSTRIAL                                       0
# KILLARNEY/GLENGARRY                                       0
#
# [100000 rows x 33 columns]

# %%
# Form features matrix X by combining the Encoded categorical Features with the numerical features
X = pd.concat([df[['Resident Count', 'Year']], categorical_columns_df_enc], axis=1)
X
# Out:
#                      Resident Count  Year  Sector_CENTRE  Sector_EAST  \
# Community Name
# WHITEHORN                     12019  2019              0            0
# FOOTHILLS                       317  2019              0            1
# ACADIA                        10520  2019              0            0
# MAHOGANY                      11784  2019              0            0
# LINCOLN PARK                   2617  2019              0            0
# ...                             ...   ...            ...          ...
# WOODBINE                       9131  2013              0            0
# NORTH GLENMORE PARK            2333  2014              0            0
# HAYSBORO                       6943  2012              0            0
# FAIRVIEW INDUSTRIAL               0  2013              0            0
# KILLARNEY/GLENGARRY            6870  2013              1            0
#
#                      Sector_NORTH  Sector_NORTHEAST  Sector_NORTHWEST  \
# Community Name
# WHITEHORN                       0                 1                 0
# FOOTHILLS                       0                 0                 0
# ACADIA                          0                 0                 0
# MAHOGANY                        0                 0                 0
# LINCOLN PARK                    0                 0                 0
# ...                           ...               ...               ...
# WOODBINE                        0                 0                 0
# NORTH GLENMORE PARK             0                 0                 0
# HAYSBORO                        0                 0                 0
# FAIRVIEW INDUSTRIAL             0                 0                 0
# KILLARNEY/GLENGARRY             0                 0                 0
#
#                      Sector_SOUTH  Sector_SOUTHEAST  Sector_WEST  ...  \
# Community Name                                                    ...
# WHITEHORN                       0                 0            0  ...
# FOOTHILLS                       0                 0            0  ...
# ACADIA                          1                 0            0  ...
# MAHOGANY                        0                 1            0  ...
# LINCOLN PARK                    0                 0            1  ...
# ...                           ...               ...          ...  ...
# WOODBINE                        1                 0            0  ...
# NORTH GLENMORE PARK             0                 0            1  ...
# HAYSBORO                        1                 0            0  ...
# FAIRVIEW INDUSTRIAL             1                 0            0  ...
# KILLARNEY/GLENGARRY             0                 0            0  ...
#
#                      Category_Assault (Non-domestic)  \
# Community Name
# WHITEHORN                                          0
# FOOTHILLS                                          0
# ACADIA                                             0
# MAHOGANY                                           0
# LINCOLN PARK                                       0
# ...                                              ...
# WOODBINE                                           0
# NORTH GLENMORE PARK                                1
# HAYSBORO                                           0
# FAIRVIEW INDUSTRIAL                                0
# KILLARNEY/GLENGARRY                                0
#
#                      Category_Commercial Break & Enter  \
# Community Name
# WHITEHORN                                            0
# FOOTHILLS                                            0
# ACADIA                                               0
# MAHOGANY                                             0
# LINCOLN PARK                                         1
# ...                                                ...
# WOODBINE                                             0
# NORTH GLENMORE PARK                                  0
# HAYSBORO                                             0
# FAIRVIEW INDUSTRIAL                                  0
# KILLARNEY/GLENGARRY                                  0
#
#                      Category_Commercial Robbery  Category_Physical Disorder  \
# Community Name
# WHITEHORN                                      0                           0
# FOOTHILLS                                      0                           0
# ACADIA                                         0                           0
# MAHOGANY                                       0                           0
# LINCOLN PARK                                   0                           0
# ...                                          ...                         ...
# WOODBINE                                       0                           1
# NORTH GLENMORE PARK                            0                           0
# HAYSBORO                                       0                           1
# FAIRVIEW INDUSTRIAL                            0                           0
# KILLARNEY/GLENGARRY                            0                           0
#
#                      Category_Residential Break & Enter  \
# Community Name
# WHITEHORN                                             0
# FOOTHILLS                                             0
# ACADIA                                                0
# MAHOGANY                                              0
# LINCOLN PARK                                          0
# ...                                                 ...
# WOODBINE                                              0
# NORTH GLENMORE PARK                                   0
# HAYSBORO                                              0
# FAIRVIEW INDUSTRIAL                                   0
# KILLARNEY/GLENGARRY                                   0
#
#                      Category_Social Disorder  Category_Street Robbery  \
# Community Name
# WHITEHORN                                   0                        1
# FOOTHILLS                                   0                        0
# ACADIA                                      0                        0
# MAHOGANY                                    0                        0
# LINCOLN PARK                                0                        0
# ...                                       ...                      ...
# WOODBINE                                    0                        0
# NORTH GLENMORE PARK                         0                        0
# HAYSBORO                                    0                        0
# FAIRVIEW INDUSTRIAL                         1                        0
# KILLARNEY/GLENGARRY                         0                        0
#
#                      Category_Theft FROM Vehicle  Category_Theft OF Vehicle  \
# Community Name
# WHITEHORN                                      0                          0
# FOOTHILLS                                      0                          1
# ACADIA                                         1                          0
# MAHOGANY                                       0                          1
# LINCOLN PARK                                   0                          0
# ...                                          ...                        ...
# WOODBINE                                       0                          0
# NORTH GLENMORE PARK                            0                          0
# HAYSBORO                                       0                          0
# FAIRVIEW INDUSTRIAL                            0                          0
# KILLARNEY/GLENGARRY                            0                          1
#
#                      Category_Violence Other (Non-domestic)
# Community Name
# WHITEHORN                                                 0
# FOOTHILLS                                                 0
# ACADIA                                                    0
# MAHOGANY                                                  0
# LINCOLN PARK                                              0
# ...                                                     ...
# WOODBINE                                                  0
# NORTH GLENMORE PARK                                       0
# HAYSBORO                                                  0
# FAIRVIEW INDUSTRIAL                                       0
# KILLARNEY/GLENGARRY                                       0
#
# [100000 rows x 35 columns]

# %%
# Instantiate MinMaxScaler object
scaler = MinMaxScaler()
scaler.fit(X) # Fit scaler to features matrix X
X_scaled = scaler.transform(X) # Transform X using Scaler to create X_scaled

# %%
X_scaled # View preview of Features Matrix X
# Out:
# array([[0.4624471 , 1.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.012197  , 1.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.40477107, 1.        , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.26714121, 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.14285714, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.26433244, 0.14285714, 1.        , ..., 0.        , 1.        ,
#         0.        ]])

# %%
# Split arrays or matrices into random train and test subsets. Use 70/30 split.
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=0.7, random_state=45)

# %%
# View dimensions of the Features Matrix X and Output Column y for both training and testing sets
print(f"Dimensions of X_train: {X_train.shape}")
print(f"Dimensions of X_test: {X_test.shape}")
print(f"Dimensions of y_train: {y_train.shape}")
print(f"Dimensions of y_test: {y_test.shape}")

# Conversion needed to pass X_train to model fit method
X_train = np.asarray(X_train).astype(np.float32)
# Conversion needed to pass y_train to model fit method
y_train = np.asarray(y_train).astype(np.float32)
# Out:
# Dimensions of X_train: (70000, 35)
# Dimensions of X_test: (30000, 35)
# Dimensions of y_train: (70000,)
# Dimensions of y_test: (30000,)

# %%
# Create Neural Network with 7 layers
model = tf.keras.Sequential ([
    tf.keras.layers.Dense (1024, input_shape=(X_train.shape[1], ), activation = 'relu',),
    tf.keras.layers.Dense (512, activation = 'relu'),
    tf.keras.layers.Dense (256, activation = 'relu'),
    tf.keras.layers.Dense (128, activation = 'relu'),
    tf.keras.layers.Dense (64, activation = 'relu'),
    tf.keras.layers.Dense (32, activation = 'relu'),
    tf.keras.layers.Dense (1, activation = 'relu')
])

# %%
# Adam optimization: a gradient descent method that is "computationally efficient, has little memory requirement, 
# invariant to diagonal rescaling of gradients, and is well suited for problems that are large in terms of data/parameters"

# MAE metric: Computes the mean absolute error between the labels and predictions.
model.compile(tf.keras.optimizers.Adam(learning_rate=0.0001), 
              loss=tf.keras.losses.MeanAbsoluteError(), 
              metrics=['mae'])

# %%
model.summary() # Print model summary
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1024)              36864
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 736,257
# Trainable params: 736,257
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=30) # Train model and observe the mean absolute error
# Out:
# Epoch 1/30
# 2188/2188 [==============================] - 23s 7ms/step - loss: 5.0222 - mae: 5.0222
# Epoch 2/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 4.4663 - mae: 4.4663
# Epoch 3/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 4.3494 - mae: 4.3494
# Epoch 4/30
# 2188/2188 [==============================] - 9s 4ms/step - loss: 4.2557 - mae: 4.2557
# Epoch 5/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 4.0301 - mae: 4.0301
# Epoch 6/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.9690 - mae: 3.9690
# Epoch 7/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.9530 - mae: 3.9530
# Epoch 8/30
# 2188/2188 [==============================] - 11s 5ms/step - loss: 3.9339 - mae: 3.9339
# Epoch 9/30
# 2188/2188 [==============================] - 9s 4ms/step - loss: 3.9198 - mae: 3.9198
# Epoch 10/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.9005 - mae: 3.9005
# Epoch 11/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.8891 - mae: 3.8891
# Epoch 12/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.8805 - mae: 3.8805
# Epoch 13/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.8693 - mae: 3.8693
# Epoch 14/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.8631 - mae: 3.8631
# Epoch 15/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.8474 - mae: 3.8474
# Epoch 16/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.8357 - mae: 3.8357
# Epoch 17/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.8260 - mae: 3.8260
# Epoch 18/30
# 2188/2188 [==============================] - 9s 4ms/step - loss: 3.8283 - mae: 3.8283
# Epoch 19/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.8104 - mae: 3.8104
# Epoch 20/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.7912 - mae: 3.7912
# Epoch 21/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.7874 - mae: 3.7874
# Epoch 22/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.7695 - mae: 3.7695
# Epoch 23/30
# 2188/2188 [==============================] - 9s 4ms/step - loss: 3.7558 - mae: 3.7558
# Epoch 24/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.7488 - mae: 3.7488
# Epoch 25/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.7450 - mae: 3.7450
# Epoch 26/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.7236 - mae: 3.7236
# Epoch 27/30
# 2188/2188 [==============================] - 9s 4ms/step - loss: 3.7220 - mae: 3.7220
# Epoch 28/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.7045 - mae: 3.7045
# Epoch 29/30
# 2188/2188 [==============================] - 10s 5ms/step - loss: 3.6901 - mae: 3.6901
# Epoch 30/30
# 2188/2188 [==============================] - 10s 4ms/step - loss: 3.6716 - mae: 3.6716

# %%
model.evaluate(X_test, y_test) # Evaulate the mean absolute error on the testing data
# Out:
# 938/938 [==============================] - 2s 2ms/step - loss: 3.7757 - mae: 3.7757
# [3.7756664752960205, 3.7756664752960205]
